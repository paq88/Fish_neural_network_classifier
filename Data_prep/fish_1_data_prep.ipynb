# %%
import numpy as np 
import pandas as pd 
import glob

# %% [markdown]
# Bash steps
#
# copy samples to different dir
# mkdir gut
# cp Gut_S* -r ./gut
#
# mkdir gut_csv_no_head
#
#
#
# use this loop to convert tsv to csv and change filename into filename containing pond
#
# for i in sed_tsv/*.tsv ; do
# dir=$(echo $i | cut -d'/' -f2)
# filename="$dir-feature_table.csv"
# echo $dir
# echo $filename
# tail -n +3 $i | sed 's/\t/,/g' > h2o_csv_no_head/$filename
# done
#
# open those files

# %%
# specifying directory containing files 
directory_path="sed_tsv/"

file_pattern = '*.csv'
file_paths = glob.glob(directory_path + file_pattern)

print(file_paths)
# Out:
# ['sed_tsv\\S08_pred_metagenome_unstrat.csv', 'sed_tsv\\S09_pred_metagenome_unstrat.csv', 'sed_tsv\\S10_pred_metagenome_unstrat.csv', 'sed_tsv\\S11_pred_metagenome_unstrat.csv', 'sed_tsv\\S12_pred_metagenome_unstrat.csv', 'sed_tsv\\S13_pred_metagenome_unstrat.csv', 'sed_tsv\\S14_pred_metagenome_unstrat.csv', 'sed_tsv\\S15_pred_metagenome_unstrat.csv', 'sed_tsv\\S16_pred_metagenome_unstrat.csv', 'sed_tsv\\S17_pred_metagenome_unstrat.csv', 'sed_tsv\\S18_pred_metagenome_unstrat.csv', 'sed_tsv\\S19_pred_metagenome_unstrat.csv', 'sed_tsv\\S20_pred_metagenome_unstrat.csv', 'sed_tsv\\S21_pred_metagenome_unstrat.csv', 'sed_tsv\\S22_pred_metagenome_unstrat.csv', 'sed_tsv\\S23_pred_metagenome_unstrat.csv', 'sed_tsv\\S24_pred_metagenome_unstrat.csv', 'sed_tsv\\S25_pred_metagenome_unstrat.csv', 'sed_tsv\\S26_pred_metagenome_unstrat.csv', 'sed_tsv\\S27_pred_metagenome_unstrat.csv', 'sed_tsv\\S28_pred_metagenome_unstrat.csv', 'sed_tsv\\S29_pred_metagenome_unstrat.csv', 'sed_tsv\\S30_pred_metagenome_unstrat.csv', 'sed_tsv\\S31_pred_metagenome_unstrat.csv', 'sed_tsv\\S32_pred_metagenome_unstrat.csv']

# %%
def pond_ex(path):
    l=path.split('\\')
    fn=l[-1]
    fn=fn.replace('_pred_metagenome_unstrat.csv','')
    return fn
#pond_ex('sed_csv_no_head\Sed_S10-feature_table.csv')

# %%
#creating initial dataframe 
result_df=pd.read_csv(file_paths[0],header=None)
result_df=result_df.T
colnames=result_df.iloc[0]
result_df.columns = colnames
result_df = result_df.drop(result_df.index[0])

result_df.insert(0,'pond',pond_ex(file_paths[0]))
result_df.head()
# Out:
# 0 pond    function              K00001 K00002              K00003 K00004  \
# 1  S08  S8.201.Sed  1159.8400000000001   19.5  2516.7200000000003  104.0
# 2  S08  S8.202.Sed  1941.6599999999999  196.5             3301.84  162.0
#
# 0 K00005 K00006 K00007   K00008  ... K19715 K19731 K19736 K19743  \
# 1  104.0   25.0    9.0  1007.38  ...  148.0  121.0    0.0    1.0
# 2  633.0    0.0   81.0   1388.0  ...  348.0    0.0   29.0   24.0
#
# 0              K19745 K19746 K19761 K19777 K19778             K19784
# 1  216.82999999999998  216.0    5.5    0.0  121.0             680.21
# 2              470.34  154.0    2.0  108.0    0.0  642.8399999999999
#
# [2 rows x 5299 columns]

# %%
# Iterate over the file paths and read each CSV file

for file_path in file_paths[1:]:
    
    df = pd.read_csv(file_path,header=None)
    df=df.T
    
    colnames=df.iloc[0]
    df.columns = colnames
    df = df.drop(df.index[0])
    df.insert(0,'pond',pond_ex(file_path))
    result_df = pd.merge(result_df, df, how='outer')
    print("Merging",file_path)


print(result_df.shape)

result_df.head(100)
# Out:
# Merging sed_tsv\S09_pred_metagenome_unstrat.csv
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 12
#      10     df = df.drop(df.index[0])
#      11     df.insert(0,'pond',pond_ex(file_path))
# ---> 12     result_df = pd.merge(result_df, df, how='outer')
#      13     print("Merging",file_path)
#      16 print(result_df.shape)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\reshape\merge.py:184, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     169 else:
#     170     op = _MergeOperation(
#     171         left_df,
#     172         right_df,
#    (...)
#     182         validate=validate,
#     183     )
# --> 184     return op.get_result(copy=copy)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\reshape\merge.py:886, in _MergeOperation.get_result(self, copy)
#     883 if self.indicator:
#     884     self.left, self.right = self._indicator_pre_merge(self.left, self.right)
# --> 886 join_index, left_indexer, right_indexer = self._get_join_info()
#     888 result = self._reindex_and_concat(
#     889     join_index, left_indexer, right_indexer, copy=copy
#     890 )
#     891 result = result.__finalize__(self, method=self._merge_type)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\reshape\merge.py:1151, in _MergeOperation._get_join_info(self)
#    1147     join_index, right_indexer, left_indexer = _left_join_on_index(
#    1148         right_ax, left_ax, self.right_join_keys, sort=self.sort
#    1149     )
#    1150 else:
# -> 1151     (left_indexer, right_indexer) = self._get_join_indexers()
#    1153     if self.right_index:
#    1154         if len(self.left) > 0:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\reshape\merge.py:1125, in _MergeOperation._get_join_indexers(self)
#    1123 # make mypy happy
#    1124 assert self.how != "asof"
# -> 1125 return get_join_indexers(
#    1126     self.left_join_keys, self.right_join_keys, sort=self.sort, how=self.how
#    1127 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\reshape\merge.py:1744, in get_join_indexers(left_keys, right_keys, sort, how)
#    1741     llab, rlab, shape = (list(x) for x in zipped)
#    1743     # get flat i8 keys from label lists
# -> 1744     lkey, rkey = _get_join_keys(llab, rlab, tuple(shape), sort)
#    1745 else:
#    1746     lkey = left_keys[0]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\reshape\merge.py:2671, in _get_join_keys(llab, rlab, shape, sort)
#    2668 rlab = [rkey] + rlab[nlev:]
#    2669 shape = (count,) + shape[nlev:]
# -> 2671 return _get_join_keys(llab, rlab, shape, sort)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\reshape\merge.py:2671, in _get_join_keys(llab, rlab, shape, sort)
#    2668 rlab = [rkey] + rlab[nlev:]
#    2669 shape = (count,) + shape[nlev:]
# -> 2671 return _get_join_keys(llab, rlab, shape, sort)
#
#     [... skipping similar frames: _get_join_keys at line 2671 (156 times)]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\reshape\merge.py:2671, in _get_join_keys(llab, rlab, shape, sort)
#    2668 rlab = [rkey] + rlab[nlev:]
#    2669 shape = (count,) + shape[nlev:]
# -> 2671 return _get_join_keys(llab, rlab, shape, sort)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\reshape\merge.py:2644, in _get_join_keys(llab, rlab, shape, sort)
#    2637 def _get_join_keys(
#    2638     llab: list[npt.NDArray[np.int64 | np.intp]],
#    2639     rlab: list[npt.NDArray[np.int64 | np.intp]],
#    (...)
#    2642 ) -> tuple[npt.NDArray[np.int64], npt.NDArray[np.int64]]:
#    2643     # how many levels can be done without overflow
# -> 2644     nlev = next(
#    2645         lev
#    2646         for lev in range(len(shape), 0, -1)
#    2647         if not is_int64_overflow_possible(shape[:lev])
#    2648     )
#    2650     # get keys for the first `nlev` levels
#    2651     stride = np.prod(shape[1:nlev], dtype="i8")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\reshape\merge.py:2647, in <genexpr>(.0)
#    2637 def _get_join_keys(
#    2638     llab: list[npt.NDArray[np.int64 | np.intp]],
#    2639     rlab: list[npt.NDArray[np.int64 | np.intp]],
#    (...)
#    2642 ) -> tuple[npt.NDArray[np.int64], npt.NDArray[np.int64]]:
#    2643     # how many levels can be done without overflow
#    2644     nlev = next(
#    2645         lev
#    2646         for lev in range(len(shape), 0, -1)
# -> 2647         if not is_int64_overflow_possible(shape[:lev])
#    2648     )
#    2650     # get keys for the first `nlev` levels
#    2651     stride = np.prod(shape[1:nlev], dtype="i8")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\sorting.py:241, in is_int64_overflow_possible(shape)
#     239 the_prod = 1
#     240 for x in shape:
# --> 241     the_prod *= int(x)
#     243 return the_prod >= lib.i8max
#
# KeyboardInterrupt:

# %%
result_df.to_csv('sed_KEGG_ortholog_merged.csv', index=False)

# %%
#merging into one big table 
sed = pd.read_csv('sed_full_feature_table.csv')
gut = pd.read_csv('gut_full_feature_table.csv')
h2o = pd.read_csv('h2o_full_feature_table.csv')

# %%
all = sed
all=all.merge(gut,how='outer')
all=all.merge(h2o,how='outer')

# %%
print(all.shape)
all.head(100)
# Out:
# (247, 336)
#        pond  \
# 0   Sed_S10
# 1   Sed_S10
# 2   Sed_S11
# 3   Sed_S11
# 4   Sed_S12
# ..      ...
# 95  Gut_S19
# 96  Gut_S19
# 97  Gut_S19
# 98  Gut_S19
# 99  Gut_S19
#
#     d__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Burkholderiales;f__Sutterellaceae  \
# 0                                               111.0
# 1                                                18.0
# 2                                                81.0
# 3                                                 3.0
# 4                                               171.0
# ..                                                ...
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
# 98                                                NaN
# 99                                                NaN
#
#     d__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Burkholderiales;f__Comamonadaceae  \
# 0                                               128.0
# 1                                               150.0
# 2                                                21.0
# 3                                                13.0
# 4                                                67.0
# ..                                                ...
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
# 98                                                NaN
# 99                                                NaN
#
#     d__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Burkholderiales;f__Rhodocyclaceae  \
# 0                                               122.0
# 1                                                10.0
# 2                                                29.0
# 3                                                18.0
# 4                                               109.0
# ..                                                ...
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
# 98                                                NaN
# 99                                                NaN
#
#     d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__Sphingobacteriales;f__Lentimicrobiaceae  \
# 0                                               101.0
# 1                                               129.0
# 2                                                90.0
# 3                                                 3.0
# 4                                                76.0
# ..                                                ...
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
# 98                                                NaN
# 99                                                NaN
#
#     d__Bacteria;p__Desulfobacterota;c__Desulfobulbia;o__Desulfobulbales;f__Desulfobulbaceae  \
# 0                                                84.0
# 1                                                 0.0
# 2                                                 NaN
# 3                                                 NaN
# 4                                                23.0
# ..                                                ...
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
# 98                                                NaN
# 99                                                NaN
#
#     d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__Chitinophagales;f__Saprospiraceae  \
# 0                                                44.0
# 1                                                 0.0
# 2                                                 8.0
# 3                                                 3.0
# 4                                                31.0
# ..                                                ...
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
# 98                                                NaN
# 99                                                NaN
#
#     d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacillales;f__Bacillaceae  \
# 0                                                42.0
# 1                                                30.0
# 2                                                10.0
# 3                                                18.0
# 4                                                 NaN
# ..                                                ...
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
# 98                                                NaN
# 99                                                NaN
#
#     d__Bacteria;p__Actinobacteriota;c__Thermoleophilia;o__Solirubrobacterales;f__67-14  \
# 0                                                52.0
# 1                                                32.0
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 1.0
# ..                                                ...
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
# 98                                                NaN
# 99                                                NaN
#
#     d__Bacteria;p__Cyanobacteria;c__Cyanobacteriia;o__Cyanobacteriales;f__Phormidiaceae  \
# 0                                               240.0
# 1                                                14.0
# 2                                                36.0
# 3                                                 0.0
# 4                                               352.0
# ..                                                ...
# 95                                               35.0
# 96                                                0.0
# 97                                                1.0
# 98                                               25.0
# 99                                                0.0
#
#     ...  \
# 0   ...
# 1   ...
# 2   ...
# 3   ...
# 4   ...
# ..  ...
# 95  ...
# 96  ...
# 97  ...
# 98  ...
# 99  ...
#
#     d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__Cytophagales;f__Cytophagaceae  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
# 98                                                NaN
# 99                                                NaN
#
#     d__Bacteria;p__Verrucomicrobiota;c__Verrucomicrobiae;o__UA11;f__UA11  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
# 98                                                NaN
# 99                                                NaN
#
#     d__Bacteria;p__Proteobacteria;c__Alphaproteobacteria;o__Reyranellales;f__Reyranellaceae  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
# 98                                                NaN
# 99                                                NaN
#
#     d__Bacteria;p__Proteobacteria;c__Alphaproteobacteria;o__Rickettsiales;f__Fokiniaceae  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
# 98                                                NaN
# 99                                                NaN
#
#     d__Bacteria;p__Verrucomicrobiota;c__Kiritimatiellae;o__Kiritimatiellales;f__Kiritimatiellaceae  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
# 98                                                NaN
# 99                                                NaN
#
#     d__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Halothiobacillales;f__Halothiobacillaceae  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
# 98                                                NaN
# 99                                                NaN
#
#     d__Bacteria;p__Myxococcota;c__Polyangia;o__Polyangiales;f__Phaselicystidaceae  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
# 98                                                NaN
# 99                                                NaN
#
#     d__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridia;f__Hungateiclostridiaceae  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
# 98                                                NaN
# 99                                                NaN
#
#     d__Bacteria;p__Patescibacteria;c__Parcubacteria;__;__  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
# 98                                                NaN
# 99                                                NaN
#
#     d__Bacteria;p__Patescibacteria;c__Parcubacteria;o__Parcubacteria;f__Parcubacteria
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
# 98                                                NaN
# 99                                                NaN
#
# [100 rows x 336 columns]

# %%
all.to_csv('all_feature_table.csv', index=False)
